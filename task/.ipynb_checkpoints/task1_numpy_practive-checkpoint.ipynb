# %% [markdown]
# # ДЗ №1 СУНЦ МГУ - Numpy practice

# %% [markdown]
# _Задачи позаимствованы из курса ML ФКН ПМИ где они были позаимствованы из курса практикума кафедры ММП факультета ВМК МГУ_

# %% [markdown]
# ### Туториальные задачи
# __(9 баллов)__
#
# Ниже приведены задачи на работу с numpy-массивами. Для каждой из задач нужно привести 2 реализации: одна без использования numpy (cчитайте, что там, где на входе или выходе должны быть numpy array, будут просто списки), а вторая полностью векторизованная (без использования питоновских циклов/map/list comprehension). Невекторизованная реализация каждой из задач оценивается в __0.5 балла__, векторизованная – в __1 балл__.
#
# Реализации без использования векторизации нужно записать в файл functions.py, а векторизованные &mdash; в файл functions_vectorized.py
#
# Для каждой задачи, приведённой ниже сравните скорость работы невекторизованной и векторизованной реализации. С помощью пакета matplotlib постройте графики времени работы в зависимости от размера данных. __Графики должны выглядеть опрятно!__ То есть должны быть подписаны оси, названия графиков, и т.д. Например, ниже представлены хороший и плохой графики:

# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

data_size = np.array([10, 30, 70, 120])
time_non_vectorized = data_size ** 2 + 10
time_vectorized = data_size ** 1.5

f, (ax1, ax2) = plt.subplots(1, 2, figsize=(13, 5))

ax1.plot(data_size, time_non_vectorized)
ax1.plot(data_size, time_vectorized)
ax1.set_title(u"Плохой график")
ax1.set_xlabel(u"Размер данных")
ax1.set_ylabel(u"Время")

ax2.plot(data_size, time_non_vectorized, label=u"Невекторизованная")
ax2.plot(data_size, time_vectorized, label=u"Векторизованная")
ax2.set_title(u"Хороший график")
ax2.set_xlabel(u"Длина массива")
ax2.set_ylabel(u"Время (с)")
ax2.grid()
ax2.legend()

f.show()
# Out:
# C:\Users\vinik\AppData\Local\Temp\ipykernel_33588\3107362156.py:26: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   f.show()

# %% [markdown]
# * __Задача 1__: Подсчитать произведение ненулевых элементов на диагонали прямоугольной матрицы.
#  Например, для X = np.array([[1, 0, 1], [2, 0, 2], [3, 0, 3], [4, 4, 4]]) ответ – 3.

# %%
import matplotlib.pyplot as plt
import numpy as np
import generator
import functions
import functions_vectorized
import time
import collect_data

# are_multisets_equal

# %matplotlib inline

def build_plot(data_size, time_non_vectorized, time_vectorized):
    f, (ax1) = plt.subplots(1, 1, figsize=(13, 5))
    ax1.plot(data_size, time_non_vectorized, label=u"Невекторизованная")
    ax1.plot(data_size, time_vectorized, label=u"Векторизованная")
    ax1.set_title("Task 1")
    ax1.set_xlabel(u"Произведение длины и ширины матрицы")
    ax1.set_ylabel(u"Время (нс)")
    ax1.grid()
    ax1.legend()
    
    f.show()
    
    
def collect_data():
    n = []
    m = []
    n = np.append(n, int(1000))
    m = np.append(m, int(1000))
    for i in range(10):
        value1 = int(n[len(n) - 1])
        value2 = int(m[len(n) - 1])

        n = np.append(n, value1 * 1.1)
        m = np.append(m, value2 * 1.1)

    print("n * m = ", np.multiply(n, m))

    First = []
    Second = []

    for i in range(len(n)):
        A = generator.generate_matrix(int(n[i]), int(m[i]), 0, 2)
        A_np = np.array(A)

        start_time = time.time_ns()
        functions_vectorized.prod_non_zero_diag(A_np)
        now = time.time_ns()
        Second = np.append(Second, now - start_time)
        
        start_time = time.time_ns()
        functions.prod_non_zero_diag(A)
        now = time.time_ns()
        First = np.append(First, now - start_time)

    print(First, Second)
    
    return np.multiply(n, m), First, Second

data_size, time_non_vectorized, time_vectorized = collect_data()

build_plot(data_size, time_non_vectorized, time_vectorized)
# Out:
# n * m =  [1000000.   1210000.   1464100.   1771561.   2143588.81 2593388.16
#  3136441.   3795093.61 4591591.84 5551678.44 6716390.56]
# [      0.       0.       0. 1001700. 1000100.  999700.  999600. 1087700.
#  1000400.  993600. 1994100.] [      0. 1000300.       0.       0.       0.       0.       0.       0.
#   749500.       0.       0.]
# C:\Users\vinik\AppData\Local\Temp\ipykernel_22020\1654413031.py:23: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   f.show()

# %% [markdown]
#
#
# * __Задача 2__: Даны два вектора x и y. Проверить, задают ли они одно и то же мультимножество.
#   Например, для x = np.array([1, 2, 2, 4]), y = np.array([4, 2, 1, 2]) ответ – True.

# %%
import matplotlib.pyplot as plt
import numpy as np
import generator
import functions
import functions_vectorized
import time
import collect_data

# are_multisets_equal

# %matplotlib inline

def build_plot(data_size, time_non_vectorized, time_vectorized):
    f, (ax1) = plt.subplots(1, 1, figsize=(13, 5))
    ax1.plot(data_size, time_non_vectorized, label=u"Невекторизованная")
    ax1.plot(data_size, time_vectorized, label=u"Векторизованная")
    ax1.set_title("Task 2")
    ax1.set_xlabel(u"Длина массива")
    ax1.set_ylabel(u"Время (с)")
    ax1.grid()
    ax1.legend()
    
    f.show()
    
    
def collect_data():
    n = []
    n = np.append(n, int(1e5))
    for i in range(25):
        value = int(n[len(n) - 1])
        n = np.append(n, value * 1.13)

    print("n = ", n)

    First = []
    Second = []

    for x in n:
        A = generator.generate_array(int(x))
        B = generator.generate_array(int(x))
        A_list = list(A)
        B_list = list(B)

        start_time = time.time()
        functions.are_multisets_equal(A_list, B_list)
        now = time.time()
        First = np.append(First, now - start_time)

        start_time = time.time()
        functions_vectorized.are_multisets_equal(A, B)
        now = time.time()
        Second = np.append(Second, now - start_time)

    print(First, Second)
    
    return n, First, Second

data_size, time_non_vectorized, time_vectorized = collect_data()

build_plot(data_size, time_non_vectorized, time_vectorized)
# Out:
# n =  [ 100000.    113000.    127688.87  144287.44  163044.31  184239.72
#   208190.07  235254.7   265837.02  300395.81  339446.35  383573.98
#   433437.49  489783.81  553454.79  625403.02  706705.39  798576.65
#   902390.88 1019700.7  1152261.   1302054.93 1471321.02 1662592.73
#  1878728.96 2122962.64]
# [0.03892636 0.04402208 0.05059004 0.05689621 0.06524706 0.07407284
#  0.08222842 0.09403944 0.10697603 0.1219449  0.14132667 0.15615201
#  0.1728394  0.19560432 0.21984625 0.26189137 0.28333712 0.31985116
#  0.38657904 0.4249475  0.496943   1.99276233 0.58748102 0.70437527
#  0.7576499  0.85105848] [0.01015496 0.00598884 0.00780749 0.00798988 0.00837159 0.01084208
#  0.01068354 0.01366639 0.01471019 0.01699901 0.01888943 0.02139473
#  0.02301049 0.02772737 0.03100657 0.03546643 0.04011607 0.04470658
#  0.0527792  0.05794477 0.06994271 0.18231964 0.08490849 0.09531593
#  0.10753036 0.1213026 ]
# ...

# %% [markdown]
# * __Задача 3__: Найти максимальный элемент в векторе x среди элементов, перед которыми стоит нулевой.
#  Например, для x = np.array([6, 2, 0, 3, 0, 0, 5, 7, 0]) ответ – 5.

# %%
import matplotlib.pyplot as plt
import numpy as np
import generator
import functions
import functions_vectorized
import time
import collect_data

# are_multisets_equal

# %matplotlib inline

def build_plot(data_size, time_non_vectorized, time_vectorized):
    f, (ax1) = plt.subplots(1, 1, figsize=(13, 5))
    ax1.plot(data_size, time_non_vectorized, label=u"Невекторизованная")
    ax1.plot(data_size, time_vectorized, label=u"Векторизованная")
    ax1.set_title("Task 3")
    ax1.set_xlabel(u"Длина массива")
    ax1.set_ylabel(u"Время (с)")
    ax1.grid()
    ax1.legend()
    
    f.show()
    
    
def collect_data():
    n = []
    n = np.append(n, int(5e5))
    for i in range(15):
        value = int(n[len(n) - 1])
        n = np.append(n, value * 1.13)

    print("n = ", n)

    First = []
    Second = []

    for x in n:
        A = generator.generate_array(int(x), -10)
        A_list = list(A)

        start_time = time.time()
        functions.max_after_zero(A_list)
        now = time.time()
        First = np.append(First, now - start_time)

        start_time = time.time()
        functions_vectorized.max_after_zero(A)
        now = time.time()
        Second = np.append(Second, now - start_time)

    print(First, Second)
    
    return n, First, Second

data_size, time_non_vectorized, time_vectorized = collect_data()

build_plot(data_size, time_non_vectorized, time_vectorized)
# Out:
# n =  [ 500000.    565000.    638450.    721447.37  815235.11  921215.55
#  1040972.95 1176298.36 1329216.74 1502014.08 1697275.82 1917920.75
#  2167249.6  2448991.37 2767359.83 3127115.67]
# [0.04301023 0.04778957 0.05647278 0.06100035 0.06901479 0.07901764
#  0.08890343 0.10001493 0.11212611 0.12610388 0.14702988 0.16803622
#  0.18207312 0.21856427 0.2325511  0.26176739] [0.00562906 0.00103807 0.00100112 0.         0.00100446 0.00099993
#  0.00100017 0.00100088 0.0010004  0.00221896 0.00200272 0.00200343
#  0.00218773 0.00300097 0.00300074 0.00299954]
# C:\Users\vinik\AppData\Local\Temp\ipykernel_22020\3339756042.py:23: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   f.show()

# %% [markdown]
#
#
# * __ Задача 4__: Дан трёхмерный массив, содержащий изображение, размера (height, width, numChannels), а также вектор длины numChannels. Сложить каналы изображения с указанными весами, и вернуть результат в виде матрицы размера (height, width). В ноутбуке приведите пример работы функции – преобразуйте цветное изображение в оттенки серого, использовав коэффициенты np.array([0.299, 0.587, 0.114]). Считать реальное изображение можно при помощи функции scipy.misc.imread (если изображение не в формате png, установите пакет pillow).

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image  # pip install Pillow
import functions as f

img = np.asarray(Image.open('image.jpg').convert('RGB'))

data = f.convert_image(img, np.array([0.299, 0.587, 0.114]))

# print(data)

pudge = Image.fromarray(data)

if pudge.mode != 'RGB':
    pudge = pudge.convert('RGB')

pudge.save('pudge1.jpg')
plt.imshow(pudge)

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image  # pip install Pillow
import functions_vectorized as fv

img = np.asarray(Image.open('image.jpg').convert('RGB'))

data = fv.convert_image(img, np.array([0.299, 0.587, 0.114]))


pudge = Image.fromarray(data)

if pudge.mode != 'RGB':
    pudge = pudge.convert('RGB')

pudge.save('pudge2.jpg')
plt.imshow(pudge)

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image  # pip install Pillow
import functions_vectorized as fv
import time

img = np.asarray(Image.open('image.jpg').convert('RGB'))

start_time = time.time()
data = fv.convert_image(img, np.array([0.299, 0.587, 0.114]))
now = time.time()

#show difference between vectorized and not

print("Not vectorized: ", now - start_time, " s")

start_time = time.time()
data = fv.convert_image(img, np.array([0.299, 0.587, 0.114]))
now = time.time()

print("Vectorized: ", now - start_time, " s")
# Out:
# Not vectorized:  0.1298525333404541  s
# Vectorized:  0.1301126480102539  s

# %% [markdown]
# * __Задача 5__: Реализовать кодирование длин серий (Run-length encoding). Для некоторого вектора x необходимо вернуть кортеж из двух векторов одинаковой длины. Первый содержит числа, а второй - сколько раз их нужно повторить.
#  Например, для x = np.array([2, 2, 2, 3, 3, 3, 5]) ответ – (np.array([2, 3, 5]), np.array([3, 3, 1])).

# %%
import matplotlib.pyplot as plt
import numpy as np
import generator
import functions
import functions_vectorized
import time
import collect_data

# are_multisets_equal

# %matplotlib inline

def build_plot(data_size, time_non_vectorized, time_vectorized):
    f, (ax1) = plt.subplots(1, 1, figsize=(13, 5))
    ax1.plot(data_size, time_non_vectorized, label=u"Невекторизованная")
    ax1.plot(data_size, time_vectorized, label=u"Векторизованная")
    ax1.set_title("Task 5")
    ax1.set_xlabel(u"Длина массива")
    ax1.set_ylabel(u"Время (с)")
    ax1.grid()
    ax1.legend()
    
    f.show()
    
    
def collect_data():
    n = []
    n = np.append(n, int(3e4))
    for i in range(28):
        value = int(n[len(n) - 1])
        n = np.append(n, value * 1.13)

    print("n = ", n)

    First = []
    Second = []

    for x in n:
        A = generator.generate_array(int(x), -1, 1)

        start_time = time.time()
        functions.run_length_encoding(A)
        now = time.time()
        First = np.append(First, now - start_time)

        start_time = time.time()
        functions_vectorized.run_length_encoding(A)
        now = time.time()
        Second = np.append(Second, now - start_time)

    print(First, Second)
    
    return n, First, Second

data_size, time_non_vectorized, time_vectorized = collect_data()

build_plot(data_size, time_non_vectorized, time_vectorized)
# Out:
# n =  [ 30000.    33900.    38307.    43286.91  48913.18  55271.69  62456.23
#   70575.28  79749.75  90116.37 101831.08 115069.03 130027.97 146930.51
#  166030.9  187613.9  212002.69 239562.26 270705.06 305896.65 345662.48
#  390598.06 441375.74 498753.75 563590.89 636856.7  719647.28 813201.11
#  918917.13]
# [0.00421929 0.00600123 0.00510097 0.00633597 0.0070014  0.00800228
#  0.00917459 0.01000285 0.01200271 0.01400304 0.01601791 0.01700401
#  0.02000475 0.02500677 0.02600622 0.02872729 0.03200722 0.03654861
#  0.04112482 0.0476017  0.05310893 0.0606339  0.06962228 0.08013654
#  0.08711505 0.09982729 0.1140244  0.1339612  0.14495254] [0.00213814 0.00201631 0.00304222 0.00306225 0.00200033 0.00400233
#  0.00422955 0.00400066 0.00500202 0.00500131 0.00600147 0.00740314
#  0.00900626 0.01200795 0.01000953 0.01238561 0.01376009 0.01702738
#  0.0177753  0.01957011 0.02168679 0.02480054 0.02908111 0.03260064
#  0.03538227 0.0411799  0.04701233 0.0550127  0.05863571]
# ...

# %% [markdown]
#
#
# * __Задача 6__: Даны две выборки объектов - X и Y. Вычислить матрицу евклидовых расстояний между объектами. Дополнительно сравните с функцией scipy.spatial.distance.cdist по скорости работы (сравнения приведите ниже в ноутбуке).

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy
import generator
import functions
import functions_vectorized
import time
import collect_data

# are_multisets_equal

# %matplotlib inline

def build_plot(data_size, time_non_vectorized, time_vectorized, time_scipy):
    f, (ax1) = plt.subplots(1, 1, figsize=(13, 5))
    ax1.plot(data_size, time_non_vectorized, label=u"Невекторизованная")
    ax1.plot(data_size, time_vectorized, label=u"Векторизованная")
    ax1.plot(data_size, time_scipy, label=u"scipy")
    ax1.set_title("Task 6")
    ax1.set_xlabel(u"Длина массива")
    ax1.set_ylabel(u"Время (с)")
    ax1.grid()
    ax1.legend()
    
    f.show()
    
    
def collect_data():
    n = []
    m = []
    n = np.append(n, int(1e2))
    m = np.append(m, int(1.5e2))
    for i in range(17):
        value = int(n[-1])
        value1 = int(m[-1])
        n = np.append(n, int(value * 1.13))
        m = np.append(m, int(value1 * 1.13))
        
    x = np.multiply(n, m)

    print("n = ", x)

    First = []
    Second = []
    Third = []

    for i in range(len(n)):
        A = generator.generate_array_of_points(int(n[i]))
        B = generator.generate_array_of_points(int(m[i]))

        start_time = time.time()
        functions.pairwise_distance(A, B)
        now = time.time()
        First = np.append(First, now - start_time)

        start_time = time.time()
        functions_vectorized.pairwise_distance(A, B)
        now = time.time()
        Second = np.append(Second, now - start_time)
        
        start_time = time.time()
        scipy.spatial.distance.cdist(A, B)
        now = time.time()
        Third = np.append(Third, now - start_time)

    print(First, Second)
    
    return x, First, Second, Third

data_size, time_non_vectorized, time_vectorized, time_scipy = collect_data()

build_plot(data_size, time_non_vectorized, time_vectorized, time_scipy)
# Out:
# n =  [ 15000.  18928.  23940.  30388.  38560.  48960.  62321.  79234. 100620.
#  128040. 163016. 207570. 264594. 337480. 430131. 548422. 699720. 892416.]
# [0.00879097 0.01106882 0.01174474 0.01421618 0.01796699 0.02168894
#  0.02978373 0.03857422 0.06113362 0.0626421  0.07734847 0.1006217
#  0.12363219 0.160429   0.21890569 0.27189875 0.38797736 0.43691897] [0.0020175  0.00199986 0.00097394 0.0018003  0.00343847 0.00460315
#  0.00484633 0.00553322 0.0092051  0.0090065  0.01279712 0.01400328
#  0.01741099 0.02200484 0.02845049 0.04100609 0.04322124 0.05501127]
# C:\Users\vinik\AppData\Local\Temp\ipykernel_39240\1019263027.py:25: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   f.show()

# %% [markdown]
# ### Туториал по Markdown
#
# __(1 балл)__
#
# Напишите краткий (а в данной домашке ещё и почти бесмысленный) отчёт с использованием 4-5 различных вариантов разметки/выделения текста.

# %% [markdown]
# # Отчет по домашке
# ## Использование numpy
# <p>Было интересно 5 часов изучать документацию <b>numpy</b> и постоянно гуглить при решении задач разные методы, однако это было полезно, я узнал пару фишек в <b>numpy</b>, и решения задач получаются весьма короткими и красивыми. </p>
#
# ## Эффективность
# <p> Что касается эффективности, то почти всегда векторизованная реализация быстрее, чем невекторизованная. Я думаю, это обусловленно тем, что numpy написан не только на python, но и на более быстрых языках. Но например в задаче 1, numpy работал <b>дольше</b>, чем обычная реализация на python, так как обычная версия работала за <i><font size="3">O(n)</font></i> без использования доп. памяти. </p>
