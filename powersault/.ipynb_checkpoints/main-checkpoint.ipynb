# %% [markdown]
# ## Setup and import some libraries

# %%
# !pip install wheel==0.38.4
# !pip install setuptools==65
# !pip install gym==0.21
# !pip install torchrl
# pip install stable-baselines3[extra]
# !pip install torchvision
# !pip install gym==0.21
# !pip install --upgrade ipykernel
# !pip install matplotlib
# !pip install gym[atari,accept-rom-license]==0.21.0
# !pip install joblib
# !pip install tqdm

# %% [markdown]
# ## Подключение библиотек

# %%
# hide imports
from IPython.display import clear_output
from PIL import Image
import matplotlib.pyplot as plt
import gym
import torchvision
import numpy as np
import torchrl
import torch
import tqdm
from torchrl.envs import *
from torchrl.envs.libs.gym import *
from joblib import Parallel, delayed
import warnings
from multiprocessing import Pool
from agent import Agent
from constants import *
warnings.filterwarnings('ignore')

random_seed = 21

torch.manual_seed(random_seed)
np.random.seed(random_seed)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

print(device)
# Out:
# cpu

# %% [markdown]
# Версия gym

# %%
gym.version.VERSION
# Out:
# '0.21.0'

# %% [markdown]
# # Действие игры происходит в среде gym "Assault"
#
# Давайте поменяем нашу среду для лучшего обучения.
#
# Во-первых сделаем resize картинки до размера 64x64 (W = 64, H = 64).
# Во-вторых переведем ее в черно-белое изображение.
# В-третьих Добавим frameskip в 4 кадра.
#
# Для этого воспользуемся классом TransformedEnv из torchrl.

# %%
#hide changing environment

_env = gym.make("ALE/Assault-v5").env

n_actions = _env.action_space.n # see more info in actions.txt

print("n_actions =", n_actions)

from torchrl.envs import *
from torchrl.envs.libs.gym import *


env = TransformedEnv(
    GymEnv("ALE/Assault-v5", from_pixels=True),
    Compose(
        ToTensorImage(in_keys=["pixels"], out_keys=["pixels_trsf"]),
        Resize(in_keys=["pixels_trsf"], w=W, h=H),
        GrayScale(in_keys=["pixels_trsf"]),
        FrameSkipTransform(4), 
        ExcludeTransform("pixels")
    ),
).to(device)
# Out:
# n_actions = 7

# %% [markdown]
# Как мы видим state это TensorDict, состоящий из нескольких параметров, в том числе done, pixels_trsf (Измененное изображение), terminated, truncated.

# %%
state = env.reset()

print(state)
# Out:
# TensorDict(
#     fields={
#         done: Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.bool, is_shared=False),
#         pixels_trsf: Tensor(shape=torch.Size([1, 84, 84]), device=cpu, dtype=torch.float32, is_shared=False),
#         terminated: Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.bool, is_shared=False),
#         truncated: Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.bool, is_shared=False)},
#     batch_size=torch.Size([]),
#     device=cpu,
#     is_shared=False)

# %% [markdown]
# ## Посмотрим, как выглядит изменная среда

# %%
state = env.reset()

print(state['pixels_trsf'].shape)

plt.imshow(state['pixels_trsf'].cpu().permute(1, 2, 0), cmap="gray")
# Out:
# torch.Size([1, 84, 84])

# %% [markdown]
# # Обучаем агента
#
# ### Для обучения агента я использую:
#   * Нейронную сеть, состоящую из сверточных и полносвязных слоев. (Подробнее смотри файл network.py)
#   * Реплей с приоритетами (TensorDictReplayBuffer) размера SIZE = 20000.
#   * Optimizer - Adam
#   * Для пересчета в Q-формуле использую target_network, которую обновляю каждые 10000 эпизодов.
#
# Для подробностей см. файл agent.py
# Также есть возможность загрузки и сохранения агента.

# %%
# создаем агента
agent = Agent(num_channels=NUM_CHANNELS, width=W, height=H, n_actions=n_actions)
# Out:
# Size of layer after convolution layers 784
# Size of layer after convolution layers 784

# %% [markdown]
# Добавим для наглядности графики

# %%
#hide plot
def plot(agent):
    clear_output(True)
    plt.figure(figsize=(20, 20))
    
    plt.subplot(221)
    plt.title('Rewards per frames')
    plt.xlabel("Frames")
    plt.ylabel("Reward")
    plt.plot(agent.frames, agent.reward_history, color='blue')
    
    plt.subplot(222)
    plt.title('Loss per frames')
    plt.xlabel("Frames")
    plt.ylabel("Loss")
    plt.plot(agent.frames, agent.loss_history, color='orange')
    
    plt.subplot(223)
    plt.title('Rewards per last 100 sessions')
    plt.xlabel("Sessions")
    plt.ylabel("Reward")
    plt.plot(agent.reward_history[-100:], color='blue')
    
    plt.subplot(224)
    plt.title('Loss per last 100 sessions')
    plt.xlabel("Sessions")
    plt.ylabel("Loss")
    plt.plot(agent.loss_history[-100:], color='orange')
    plt.show()

# %% [markdown]
# Играем сессию и записываем в агента опыт

# %%
# hide session
def play_session(agent, t_max=(int)(1e5), epsilon=0):
    env = TransformedEnv(
    GymEnv("ALE/Assault-v5", from_pixels=True),
        Compose(
            ToTensorImage(in_keys=["pixels"], out_keys=["pixels_trsf"]),
            Resize(in_keys=["pixels_trsf"], w=W, h=H),
            GrayScale(in_keys=["pixels_trsf"]),
            FrameSkipTransform(4), 
            ExcludeTransform("pixels")
        ),
    ).to(device) # все как мы любим, изменненая среда.

    total_reward = 0
    state = env.reset()
    
    frames = 0

    for t in range(t_max):
        action = agent.select_action(state['pixels_trsf'], epsilon=epsilon)

        state['action'] = torch.zeros(n_actions)
        state['action'][action] = 1

        next_state = env.step(state)['next']

        next_state['done'] = next_state['done'] + next_state['terminated'] + next_state['truncated']
        next_state.pop('truncated', None)
        next_state.pop('terminated', None)

        state['next'] = next_state

        agent.record_experience(state)

        total_reward += next_state['reward']

        state = next_state
        
        frames += 1

        if next_state['done']:
            break
    
    return total_reward, frames

# %% [markdown]
# ### Выбираем будем ли тренироваться и загружаться

# %%
loading = True
training = True

# %%
if training:
    if loading:
        agent.load()

    agent.save()

    print("preparing (add random states to replay buffer)")
    if not loading:
        pass
    else:
        Parallel(n_jobs=-1, require='sharedmem', verbose=30)(delayed(play_session)(agent, epsilon=0.3) for _ in range(pre_training_iterations))
    
    epoch = 0
    while True:
        rewards_for_session, count_frames = play_session(agent, t_max=(int)(agent.t_max), epsilon=agent.epsilon)
        rewards_for_session = np.asarray(torch.as_tensor(rewards_for_session).cpu())
        
        agent.epsilon *= 0.996

        loss = agent.train(16)
        agent.loss_history.append(loss)
        agent.reward_history.append(np.mean(rewards_for_session))
        last_frames = 0
        if len(agent.frames) != 0:
            last_frames = agent.frames[-1]
        agent.frames.append(last_frames + count_frames)
        clear_output(True)
        
        plot(agent)
        print("for frame = ", last_frames + count_frames, ", epsilon = ", agent.epsilon)


        if agent.epsilon < 0.1:
            agent.epsilon = 0.2
        
        agent.t_max *= 1.01
        epoch += 1
        agent.t_max = min(agent.t_max, (int)(4e4))

        if epoch % 10 == 1:
            agent.save()
            print('saved successfully')
# Out:
# for frame =  4454986 , epsilon =  0.1960318722557952
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 15
#      13 epoch = 0
#      14 while True:
# ---> 15     rewards_for_session, count_frames = play_session(agent, t_max=(int)(agent.t_max), epsilon=agent.epsilon)
#      16     rewards_for_session = np.asarray(torch.as_tensor(rewards_for_session).cpu())
#      18     agent.epsilon *= 0.996
#
# Cell In[9], line 25, in play_session(agent, t_max, epsilon)
#      22 state['action'] = torch.zeros(n_actions)
#      23 state['action'][action] = 1
# ---> 25 next_state = env.step(state)['next']
#      27 next_state['done'] = next_state['done'] + next_state['terminated'] + next_state['truncated']
#      28 next_state.pop('truncated', None)
#
# File ~\anaconda3\Lib\site-packages\torchrl\envs\common.py:1313, in EnvBase.step(self, tensordict)
#    1310 self._assert_tensordict_shape(tensordict)
#    1311 next_preset = tensordict.get("next", None)
# -> 1313 next_tensordict = self._step(tensordict)
#    1314 next_tensordict = self._step_proc_data(next_tensordict)
#    1315 if next_preset is not None:
#    1316     # tensordict could already have a "next" key
#    1317     # this could be done more efficiently by not excluding but just passing
#    1318     # the necessary keys
#
# File ~\anaconda3\Lib\site-packages\torchrl\envs\transforms\transforms.py:725, in TransformedEnv._step(self, tensordict)
#     723 next_preset = tensordict.get("next", None)
#     724 tensordict_in = self.transform.inv(tensordict)
# --> 725 next_tensordict = self.base_env._step(tensordict_in)
#     726 if next_preset is not None:
#     727     # tensordict could already have a "next" key
#     728     # this could be done more efficiently by not excluding but just passing
#     729     # the necessary keys
#     730     next_tensordict.update(
#     731         next_preset.exclude(*next_tensordict.keys(True, True))
#     732     )
#
# File ~\anaconda3\Lib\site-packages\torchrl\envs\gym_like.py:248, in GymLikeEnv._step(self, tensordict)
#     245     if do_break:
#     246         break
# --> 248 reward = self.read_reward(reward)
#     249 obs_dict = self.read_obs(obs)
#     251 if reward is None:
#
# File ~\anaconda3\Lib\site-packages\torchrl\envs\gym_like.py:196, in GymLikeEnv.read_reward(self, reward)
#     189 def read_reward(self, reward):
#     190     """Reads the reward and maps it to the reward space.
#     191
#     192     Args:
#     193         reward (torch.Tensor or TensorDict): reward to be mapped.
#     194
#     195     """
# --> 196     return self.reward_spec.encode(reward, ignore_device=True)
#
# File ~\anaconda3\Lib\site-packages\torchrl\data\tensor_specs.py:565, in TensorSpec.encode(self, val, ignore_device)
#     563 else:
#     564     try:
# --> 565         val = val.reshape(self.shape)
#     566     except Exception as err:
#     567         raise RuntimeError(
#     568             f"Shape mismatch: the value has shape {val.shape} which "
#     569             f"is incompatible with the spec shape {self.shape}."
#     570         ) from err
#
# KeyboardInterrupt:

# %%
if not training:
    pass # lets see result!
